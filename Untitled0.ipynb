# %% [markdown]
# <a href="https://colab.research.google.com/github/oksa27b/Budoksa/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# C++
# int n = 5; -> []
# n = 5 -> class <"int"> -> []
# переменная это переадресация и связка нас с ячейкой
#geekbrainds = 5
#skillbox = 10

# Сложение
#print(geekbrainds+skillbox);


#a = input() 
#b = input()

#Сложение
#print((a + b) * 5)


#a = int(input()) 
#b = int(input())

#print(a + b)



#a = int(input("Введите первое число: ")) 
#b = int(input("Введите первое число: ")) 

#print(a + b)




#a = int(input("Введите первое число: ")) 
#b = int(input("Введите первое число: ")) 

#print(f"{a} + {b} = {a + b}")






#Список это коллекция данных, в которых мы можем хранить любые данные


#a = int(input("Введите первое число: ")) 
#b = int(input("Введите первое число: "))

#print(f"{a} + {b} = {a + b}")





#Бинарный поиск
#array = (2, 7, 10, 14, 18, 19, 20, 34, 42, 47, 69)
#        0  1   2
#left = 0
#riht = len(array) - 1
# = (left + right) // 2
#while left <= right:
#  middle = (left + right) // 2
#  ansver = input(f"Это число больше {array(middle)}? --")
#  if ansver.lower() == "да":
#    left = middle + 1
#  elif ansver.lower() == "нет":
#    right = middle - 1  
#  else:
#    print("Вы ответили верно. Укажите "да" или "нет"")
#  print(array(middle))



#загадывать числа
#63
#50-100



#Пузырьковая сортировка

#array = (5, 4, 3, 2, 1)
# 5 4 -> 4 5 
#array = (1, 2, 3, 4, 5)
# 5 3 -> 3 5 
#array (4, 3, 5, 2, 1)
#for i in range(len(array)):
#  for J in (len(array) - 1):
#    if array[j] > array[j +1]:
#      temp = array[j]
#      array[j] = array[j + 1]
#      array[j + 1] = temp
#print(array)



#Игра НИМ
from random import randint

n = int(input("Введите количество комней в куче? --"))
count = 1
while n > 0:
  count = count + 1
  if count % 2 == 0:
    comp = randint(1, 3)
    print(f"Компьютер ввел {comp} камней")
    n = n - comp
    print(f"Количество камней осталось {n}")
    if n <= 0:
      print("Компьютер победил!")
  else:
    player = int(input("Введите количество камней(от 1 до 3):"))
    while player < 1 or player > 3:
      print("Вы ошиблись!")
      player = int(input("Введите количество камней(от 1 до 3):"))

    n = n - player
    print(f"Количество камней осталось {n}")
    if n <= 0:
      print("Вы победили!")
# Out:
# Введите количество комней в куче? --10
# Компьютер ввел 1 камней
# Количество камней осталось 9
# Введите количество камней(от 1 до 3):3
# Количество камней осталось 6
# Компьютер ввел 2 камней
# Количество камней осталось 4
# Введите количество камней(от 1 до 3):2
# Количество камней осталось 2
# Компьютер ввел 1 камней
# Количество камней осталось 1
# Введите количество камней(от 1 до 3):1
# Количество камней осталось 0
# Вы победили!
